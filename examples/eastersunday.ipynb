# %%
import sys
sys.path.append('..')
import yearfrac as yf
from datetime import datetime

# %%
y = 2019
m, d = yf.eastersunday(y)
print(datetime(y, m, d))
# Out:
# 2019-04-21 00:00:00

# %%
for y in range(1583, 4099+1):
    m, d = yf.eastersunday(y)
    print(datetime(y, m, d))
# Out:
# 1583-04-10 00:00:00
# 1584-04-01 00:00:00
# 1585-04-21 00:00:00
# 1586-04-06 00:00:00
# 1587-03-29 00:00:00
# 1588-04-17 00:00:00
# 1589-04-02 00:00:00
# 1590-04-22 00:00:00
# 1591-04-14 00:00:00
# 1592-03-29 00:00:00
# 1593-04-18 00:00:00
# 1594-04-10 00:00:00
# 1595-03-26 00:00:00
# 1596-04-14 00:00:00
# 1597-04-06 00:00:00
# 1598-03-22 00:00:00
# 1599-04-11 00:00:00
# 1600-04-02 00:00:00
# 1601-04-22 00:00:00
# 1602-04-07 00:00:00
# 1603-03-30 00:00:00
# 1604-04-18 00:00:00
# 1605-04-10 00:00:00
# 1606-03-26 00:00:00
# 1607-04-15 00:00:00
# 1608-04-06 00:00:00
# 1609-04-19 00:00:00
# 1610-04-11 00:00:00
# 1611-04-03 00:00:00
# 1612-04-22 00:00:00
# 1613-04-07 00:00:00
# 1614-03-30 00:00:00
# 1615-04-19 00:00:00
# 1616-04-03 00:00:00
# 1617-03-26 00:00:00
# 1618-04-15 00:00:00
# 1619-03-31 00:00:00
# 1620-04-19 00:00:00
# 1621-04-11 00:00:00
# 1622-03-27 00:00:00
# 1623-04-16 00:00:00
# 1624-04-07 00:00:00
# 1625-03-30 00:00:00
# 1626-04-12 00:00:00
# 1627-04-04 00:00:00
# ...
